# %%
# Importing libraries and dependencies 
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os
from langchain.schema import HumanMessage, SystemMessage
from IPython.display import display
import google.generativeai as genai

# %%
# Loading the environment variables.
load_dotenv()

# Storing the API key in a variable to access later on 
GEMINI_API_KEY = os.getenv("GEMINI_API_KEY")

# Configuring the model as recommended on Google's help guide 
genai.configure(api_key=GEMINI_API_KEY)

model = genai.GenerativeModel("gemini-1.5-flash")

# %%
# Starting to collect user input (workout goals, and if they want to follow)
def get_user_preferences():
    """Collect user goals and preferences."""
    user_goals = input("Enter your fitness goal (e.g., 'build muscle', 'lose weight'): ")
    celebrity_choice = input("Enter a celebrity's name if you'd like to follow their workout (or leave blank): ")
    return {
        "fitness_goal": user_goals,
        "celebrity_preference": celebrity_choice
    }
user_preferences = get_user_preferences()

# %%
# Fetching data based off user input 
def fetch_workout_data(goal, celebrity=None):
    """Fetch workout data using Google Gemini API based on user's goal and celebrity preference"""
    prompt = f"Create a workout plan for someone whose goal is to {goal}"
    if celebrity: 
        prompt += f" Include a workout inspired by {celebrity}"
    try:
        response = model.generate_content(prompt)
        return response.text
    except Exception as e:
        return f"Error fetching workout data: {str(e)}"

# This code will help find a meal plan based on the user's workout goals above
def fetch_meal_plan(goal):
    """Fetch meal plan using Google Gemini API based on the user's goal."""
    prompt = f"Create a meal plan to support the goal of {goal}."
    
    try: 
        response = model.generate_content(prompt)
        return response.text
    except Exception as e: 
        return f"Error fetching meal plan data {str(e)}"
workout_plan = fetch_workout_data(user_preferences["fitness_goal"], user_preferences.get("celebrity_preference"))
meal_plan = fetch_meal_plan(user_preferences["fitness_goal"])
print("Workout Plan:")
print(workout_plan)
print("Meal plan")
print(meal_plan)
# Out:
# Workout Plan:
# ## Muscle Building Workout Plan (Beginner - Intermediate)
#
# This plan focuses on compound exercises to maximize muscle growth and requires 3-4 workouts per week with rest days in between.  Adjust the weight to challenge yourself while maintaining good form.  Prioritize proper technique over lifting heavy weight.
#
# **Warm-up (5-10 minutes before each workout):**
#
# * Light cardio, like jogging in place or jumping jacks (2 minutes)
# * Dynamic stretching, such as arm circles, leg swings, torso twists (3-5 minutes)
#
# **Workout A (Focus: Upper Body)**
#
# * **Bench Press:** 3 sets of 8-12 repetitions
# * **Overhead Press:** 3 sets of 8-12 repetitions
# * **Bent-Over Rows:** 3 sets of 8-12 repetitions
# * **Bicep Curls:** 3 sets of 10-15 repetitions
# * **Triceps Pushdowns:** 3 sets of 10-15 repetitions
#
# **Workout B (Focus: Lower Body & Core)**
#
# * **Squats:** 3 sets of 8-12 repetitions
# * **Romanian Deadlifts:** 3 sets of 10-15 repetitions
# * **Leg Press:** 3 sets of 10-15 repetitions
# * **Hamstring Curls:** 3 sets of 10-15 repetitions
# * **Calf Raises:** 3 sets of 15-20 repetitions
# * **Plank:** 3 sets, hold for 30-60 seconds
# * **Crunches:** 3 sets of 15-20 repetitions
#
# **Workout C (Focus: Full Body - Optional, can be substituted for a rest day or used as an active recovery day)**
#
# * **Push-ups:** 3 sets to failure
# * **Pull-ups (or assisted pull-ups):** 3 sets to failure
# * **Walking Lunges:** 3 sets of 10-12 repetitions per leg
# * **Dumbbell Rows:** 3 sets of 10-12 repetitions per side
# * **Burpees:** 3 sets of 10 repetitions
#
#
# **Cool-down (5-10 minutes after each workout):**
#
# * Static stretching, holding each stretch for 20-30 seconds. Focus on major muscle groups worked during the workout.
#
#
# **Workout Schedule (Example):**
#
# * **Monday:** Workout A
# * **Tuesday:** Workout B
# * **Wednesday:** Rest or Workout C (Active Recovery)
# * **Thursday:** Workout A
# * **Friday:** Workout B
# * **Saturday & Sunday:** Rest
#
#
# **Important Considerations:**
#
# * **Progressive Overload:** Gradually increase the weight, reps, or sets over time to continually challenge your muscles.  This is crucial for muscle growth.
# * **Proper Form:** Focus on maintaining correct form throughout each exercise to prevent injuries and maximize effectiveness. Watch videos and, if possible, consult with a trainer to ensure proper technique.
# * **Nutrition:**  Consume a sufficient amount of protein (around 1 gram per pound of body weight) to support muscle growth.  Also, ensure you're eating enough calories to fuel your workouts and recovery.
# * **Rest and Recovery:**  Adequate sleep (7-9 hours per night) is essential for muscle recovery and growth.  Don't neglect rest days.
# * **Listen to your body:** If you experience pain, stop the exercise and rest. Don't push yourself too hard, especially when starting.
# * **Progression:** After several weeks of consistent training, you may want to consider more advanced variations of the exercises or add new exercises to continue challenging your muscles.  You can also increase the number of sets or reps.
#
# This is a sample plan and might need adjustments based on your individual needs and fitness level.  Consider consulting with a certified personal trainer for a personalized plan.  They can help you assess your fitness level, design a program tailored to your goals, and teach you proper exercise techniques.
#
# Meal plan
# ## Muscle Building Meal Plan (Example - Adjust Calories & Macros Based on Your Needs)
#
# This is a sample meal plan for a moderately active individual aiming to build muscle.  **You MUST adjust the calorie and macronutrient (protein, carbohydrate, fat) quantities based on your individual needs, including your weight, activity level, and training intensity.**  Consult a registered dietitian or certified personal trainer for personalized guidance.
#
# **Daily Calorie Target (Example):** 2800-3000 calories (Adjust based on your individual needs)
#
# **Macronutrient Ratio (Example):** 40% Carbohydrates, 35% Protein, 25% Fat
#
# **Note:**  This meal plan emphasizes whole, unprocessed foods.  Portion sizes should be adjusted to meet your individual caloric needs.
#
# **Day 1:**
#
# * **Breakfast (approx. 500 calories):** Oatmeal (1 cup) with whey protein powder (1 scoop), berries (1/2 cup), nuts (1/4 cup)
# * **Mid-Morning Snack (approx. 200 calories):** Greek yogurt (1 cup) with fruit (1/2 cup) and a handful of almonds
# * **Lunch (approx. 700 calories):** Grilled chicken breast (6 oz) salad with mixed greens, quinoa (1 cup), avocado (1/4), and olive oil dressing
# * **Pre-Workout Snack (approx. 150 calories):** Banana with peanut butter (2 tbsp)
# * **Post-Workout Snack (approx. 250 calories):** Whey protein shake (1 scoop) with milk (1 cup)
# * **Dinner (approx. 800 calories):** Baked salmon (6 oz) with sweet potato (1 medium) and steamed broccoli (1 cup)
#
#
# **Day 2:**
#
# * **Breakfast (approx. 450 calories):** Scrambled eggs (3) with spinach and whole-wheat toast (2 slices)
# * **Mid-Morning Snack (approx. 200 calories):** Protein bar (choose one with at least 20g protein)
# * **Lunch (approx. 750 calories):**  Lean ground beef (4 oz) stir-fry with brown rice (1 cup) and plenty of vegetables (broccoli, peppers, onions)
# * **Pre-Workout Snack (approx. 150 calories):** Apple slices with almond butter (2 tbsp)
# * **Post-Workout Snack (approx. 250 calories):** Casein protein shake (1 scoop) with water
# * **Dinner (approx. 800 calories):** Chicken breast (6 oz) with brown rice (1 cup) and asparagus (1 cup)
#
#
# **Day 3:**
#
# * **Breakfast (approx. 500 calories):**  Protein pancakes (made with protein powder) with berries and a drizzle of maple syrup
# * **Mid-Morning Snack (approx. 200 calories):** Cottage cheese (1 cup) with sliced peaches
# * **Lunch (approx. 700 calories):** Turkey breast (6 oz) sandwich on whole-wheat bread with lettuce, tomato, and mustard
# * **Pre-Workout Snack (approx. 150 calories):**  Small handful of trail mix
# * **Post-Workout Snack (approx. 250 calories):**  Whey protein shake (1 scoop) with milk (1 cup)
# * **Dinner (approx. 800 calories):**  Lentil soup (1.5 cups) with a whole-wheat roll
#
#
# **Day 4-7:**  Repeat and vary meals from Days 1-3, incorporating other lean protein sources (like turkey, fish, beans, lentils), complex carbohydrates (like brown rice, quinoa, sweet potatoes), and healthy fats (like avocados, nuts, seeds, olive oil).
#
# **Important Considerations:**
#
# * **Hydration:** Drink plenty of water throughout the day.
# * **Supplementation:** While not necessary, creatine and whey protein can be beneficial for muscle growth. Consult a healthcare professional before starting any supplements.
# * **Progressive Overload:**  To build muscle, you need to progressively increase the weight, reps, or sets in your workouts over time.
# * **Sleep:** Aim for 7-9 hours of quality sleep per night for muscle recovery and growth.
# * **Consistency:**  Stick to your meal plan and workout routine consistently for optimal results.
#
# This is just a sample meal plan.  Remember to consult with a professional to create a personalized plan that aligns with your individual needs and goals.  Adjust portions and food choices based on your preferences and dietary restrictions.  The key is to consume enough calories and protein to support muscle growth while maintaining a healthy overall diet.
